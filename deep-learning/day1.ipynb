# %%
## fundamental of tensors

# %%
import torch    
import numpy as np

# %%
## 1d, 2d, 3d tensors

# %%
a=[10,20,30]
b=[10]
c=[[10,20,30],[12,23,25]]

# %%
aa=torch.tensor(a)
bb=torch.tensor(b)
cc=torch.tensor(c)

# %%
print(a,aa)
# Out:
# [10, 20, 30] tensor([10, 20, 30])

# %%
aaa=np.linspace(1,20,10)

# %%
aaa
# Out:
# array([ 1.        ,  3.11111111,  5.22222222,  7.33333333,  9.44444444,
#        11.55555556, 13.66666667, 15.77777778, 17.88888889, 20.        ])

# %%
aaaa=torch.tensor(aaa)
# Out:
# /tmp/ipykernel_30880/3934296434.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   aaaa=torch.tensor(aaa)

# %%
random_tensor=torch.rand((2,4))

# %%
random_tensor
# Out:
# tensor([[0.8558, 0.2413, 0.4870, 0.1398],
#         [0.3970, 0.3154, 0.2183, 0.8417]])
