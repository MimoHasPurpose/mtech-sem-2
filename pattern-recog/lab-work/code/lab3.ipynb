# %% [markdown]
# ### Experiment 3: Linear and Quadratic Discriminant Analysis for multi-class pattern classification

# %% [markdown]
# ### Theory

# %% [markdown]
# - LDA, QDA are two classifiers which have a linear and quadratic decision surface
# - closed form solution
# - inherently multiclass
# - no hyperparameters
# - ![image.png](attachment:6b3da6ee-1161-4bd6-baad-0e1a144b5f70.png)
